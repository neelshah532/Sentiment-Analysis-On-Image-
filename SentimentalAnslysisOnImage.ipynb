# %%
import cv2 #pip/pip3 install opencv-python & pip/pip3 install opencv-contrib-python
from deepface import DeepFace # pip/pip3 install deepface

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread("angery_emoji.jpg")

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
try:
  predictions= DeepFace.analyze(img , enforce_detection=False)

except:
  print("No face detetecd")
predictions,
#predictions = DeepFace.analyze(img , enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.54it/s]
# ([{'emotion': {'angry': 0.979678425937891,
#     'disgust': 5.435088143435074e-10,
#     'fear': 9.87653061747551,
#     'happy': 0.002104374289046973,
#     'sad': 3.421170637011528,
#     'surprise': 0.017677694268058985,
#     'neutral': 85.70284247398376},
#    'dominant_emotion': 'neutral',
#    'region': {'x': 0, 'y': 0, 'w': 122, 'h': 122},
#    'age': 26,
#    'gender': {'Woman': 1.2127730995416641, 'Man': 98.78722429275513},
#    'dominant_gender': 'Man',
#    'race': {'asian': 29.708445072174072,
#     'indian': 0.3747182199731469,
#     'black': 0.3920091316103935,
#     'white': 46.233901381492615,
#     'middle eastern': 21.876834332942963,
#     'latino hispanic': 1.4140932820737362},
#    'dominant_race': 'white'}],)

# %%
type(predictions[0])
predictions[0]['dominant_emotion']
# Out:
# 'neutral'

# %%
#prediction = dict(predictions)
#type(predictions)
#predictions[:1]

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)

for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
           predictions[0]['dominant_emotion'],
           (0,50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
